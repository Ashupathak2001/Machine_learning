# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashupathak2001/Machine_learning/blob/main/Classifying_Images_of_Everyday_Objects_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Classifying Images of Everyday Objects**
#
# In this notebook we'll build a neural networks with many hidden layers to classify images of CIFAR10 dataset. This dataset consists of 60,000 32x32 colour images in 10 classes, with 6,000 images per class. There are 50,000 training images and 10,000 test images.
#
# The whole process of classifying is similar to the one of notebook Training Deep Neural Networks on a GPU, except that the neural network class Cifar10Model has dynamique hidden layers, the number of hidden layers depends on the given hidden sizes.

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torchvision.datasets import CIFAR10
from torchvision.transforms import ToTensor
from torch.utils.data import random_split
from torch.utils.data.dataloader import DataLoader
from torchvision.utils import make_grid
import torch.nn as nn
import torch.nn.functional as F
import torch

# %%
# Download data
dataset=CIFAR10(root="data/",transform=ToTensor(),train=True,download=True)
test_ds=CIFAR10(root="data/",transform=ToTensor(),train=False)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43486877.58it/s]
# Extracting data/cifar-10-python.tar.gz to data/

# %%
# Explore data
# attribute & methods of the variable dataset
# get all attribute
atts=[att for att in vars(dataset).keys() if not callable(vars(dataset)[att])]
print("dataset attribute : %s" %atts)
# get all methods
methods=[m for m in vars(dataset).keys() if callable(vars(dataset)[m])]
print("dataset methods: %s" %methods)
# Out:
# dataset attribute : ['root', 'target_transform', 'train', 'data', 'targets', 'classes', 'class_to_idx']
# dataset methods: ['transform', 'transforms']

# %%
# get the dataset size
print("datset size ={:,}".format(len(dataset)))
print("test set size={:,}".format(len(test_ds)))
# Out:
# datset size =50,000
# test set size=10,000

# %%
# Output classes & output size
classes=dataset.classes
print("output classes: %s" %classes)
print("output size : %s" %len(classes))
# Out:
# output classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# output size : 10

# %%
# shape of an image in dataset
img,label=dataset[10]
print("image shape = %s" %list(img.shape))
# Out:
# image shape = [3, 32, 32]

# %%
plt.imshow(img.permute(1,2,0))
print("label (numeric): %s" %label)
print("label(texture): %s" %classes[label])
# Out:
# label (numeric): 4
# label(texture): deer

# %%
# get teh number of images in each class
cls_stats=dict(zip(classes,[0]*len(classes)))
for _, label in dataset:
  k=classes[label]
  cls_stats[k]+=1

# %%
for k, v in cls_stats.items():
  print("{}:{:,}".format(k, v))
# Out:
# airplane:5,000
# automobile:5,000
# bird:5,000
# cat:5,000
# deer:5,000
# dog:5,000
# frog:5,000
# horse:5,000
# ship:5,000
# truck:5,000

# %%
# show images in dataset
images = list()
for i in range(128):
  img, _=dataset[i]
  images.append(img)

# %%
fig=plt.figure(figsize=(16,8))
plt.axis("off")
plt.imshow(make_grid(images, nrow=16).permute((1,2,0)))

# %%
# create datasets & data loaders
val_size=7000
train_size=len(dataset)-val_size

# %%
torch.manual_seed(43)
train_ds, val_ds =random_split(dataset, [train_size,val_size])
print("training dataset size = {:,}".format(len(train_ds)))
print("validation dataset size = {:,}".format(len(val_ds)))
# Out:
# training dataset size = 43,000
# validation dataset size = 7,000

# %%
batch_size=128
train_loader=DataLoader(train_ds,batch_size,num_workers=4,pin_memory=True,shuffle=True)
val_loader=DataLoader(val_ds,batch_size*2,num_workers=4,pin_memory=True)
test_loader=DataLoader(test_ds,batch_size*2,num_workers=4,pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %% [markdown]
# **Create Neural Network**

# %%
class Cifar10Model(nn.Module):
  def __init__(self,in_features:int,out_classes:int,hidden_sizes:list):
    super().__init__()
    self.linear1=nn.Linear(in_features,hidden_sizes[0])
    self.nb_hidden_layers=len(hidden_sizes)
    for i in range(self.nb_hidden_layers):
      func_name="linear%s" %(i+2)
      if i+1 ==self.nb_hidden_layers:
        func=nn.Linear(hidden_sizes[i],out_classes)
      else:
        func=nn.Linear(hidden_sizes[i],hidden_sizes[i+1])
      setattr(self,func_name,func)

  def forward(self, X:torch.tensor) -> torch.tensor:
        """Compute linear prediction of image(s)

        Args:
            X (torch.tensor): input image(s)

        Returns:
            torch.tensor: linear prediction of image(s)
        """
        # flatten image
        X = X.reshape(-1, self.linear1.in_features)
        # compute activation units of hidden layers
        A = X
        for i in range(self.nb_hidden_layers):
            func = getattr(self, "linear%s" % (i+1))
            Z = func(A)
            A = F.relu(Z)
        # compute linear prediction
        func = getattr(self, "linear%s" % (self.nb_hidden_layers+1))
        Y_linear = func(A)
        return Y_linear

  def predict(self, X:torch.tensor) -> torch.tensor:
        """Predict class(es) of image(s)

        Args:
            X (torch.tensor): input image(s)

        Returns:
            torch.tensor: class(es) predicted
        """
        Y_linear = self(X)
        probs = F.softmax(Y_linear.detach(), dim=1)
        _, Y_hat = torch.max(probs, dim=1)
        return Y_hat

  def cost_func(self, batch:list) -> torch.tensor:
        """Compute cost of prediction(s)

        Args:
            batch (list): containing 2 values images & labels

        Returns:
            torch.tesor: the cost
        """
        images, labels = batch
        Y_linear = self(images)
        cost = F.cross_entropy(Y_linear, labels)
        return cost

  def evaluate(self, batch:list) -> dict:
        """Compute cost & accuracy of prediction(s)

        Args:
            batch (list): containing 2 values images & labels

        Returns:
            dict: containing 2 keys "cost" & "accuracy"
        """
        images, labels = batch
        Y_hat = self.predict(images)
        acc = torch.sum(Y_hat == labels).item()/len(Y_hat)
        Y_linear = self(images)
        cost = F.cross_entropy(Y_linear.detach(), labels).item()
        res = {
            "cost": cost,
            "accuracy": acc
        }
        return res

# %%
in_features=3*32*32
out_classes=10
hidden_sizes=[128, 128]

# %%
model=Cifar10Model(in_features,out_classes,hidden_sizes)

# %% [markdown]
# **Using GPU**

# %%
def getDefaultDevice():
    """Pick GPU if available, else CPU
    """
    if torch.cuda.is_available():
        return torch.device("cuda")
    return torch.device("cpu")

# %%
def toDevice(data, device:torch.device):
    """Move tensor(s) to chosen device

    Args:
        device (torch.device): device to move tensor(s) to
    """
    if isinstance(data, (list, tuple)):
        return [toDevice(x, device) for x in data]
    return data.to(device, non_blocking=True)

# %%
class DeviceDataLoader():
    """This class is to wrap data loader and move batches of data
    to the selected device
    """
    def __init__(self, dataloader:DataLoader, device:torch.device):
        self.dataloader = dataloader
        self.device = device

    def __iter__(self):
        """This method is to retrieve batches of data
        """
        for batch in self.dataloader:
            yield toDevice(batch, self.device)

    def __len__(self):
        """This method is to get the number of batches
        """
        return len(self.dataloader)

# %%
device = getDefaultDevice()
toDevice(model, device)
train_loader = DeviceDataLoader(train_loader, device)
val_loader = DeviceDataLoader(val_loader, device)
test_loader = DeviceDataLoader(test_loader, device)

# %%
print("device used : %s" % device.type)
# Out:
# device used : cuda

# %% [markdown]
# **Train Model**

# %%
def evaluateEpoch(batch_evals:list, decimals=3) -> dict:
    """Get cost & accuracy of predictions of an epoch

    Args:
        batch_evals (list): list of batch evaluations
        decimals (int, optional): decimals to round values

    Returns:
        dict: containing 2 keys "cost" & "accuracy"
    """
    batch_costs = [x["cost"] for x in batch_evals]
    batch_accs = [x["accuracy"] for x in batch_evals]
    cost = sum(batch_costs)/len(batch_costs)
    acc = sum(batch_accs)/len(batch_accs)
    res = {
        "cost": round(cost, decimals),
        "accuracy": round(acc, decimals)
    }
    return res

# %%
def fit(epochs:int, model:Cifar10Model, optimizer:torch.optim,
        train_loader:DataLoader, val_loader:DataLoader) -> list:
    """Train model

    Args:
        epochs (int): number of iterations
        model (Cifar10Model): model to train
        optimizer (torch.optim): function to optimize model parameters
        train_loader (DataLoader): data loader for training phase
        val_loader (DataLoader): data loader for validation phase

    Returns:
        list: evaluation results of epochs
    """
    logs = list()
    for i in range(epochs):
        # training phase
        for batch in train_loader:
            cost = model.cost_func(batch)
            cost.backward()
            optimizer.step()
            optimizer.zero_grad()

        # validation phase
        batch_evals = [model.evaluate(batch) for batch in val_loader]
        res = evaluateEpoch(batch_evals)
        logs.append(res)
        print("epoch %s: validation cost = %s, validation accuracy = %s" %
              (i+1, res["cost"], res["accuracy"]))
    return logs

# %%
epochs = 10
lr = 1e-1
optimizer = torch.optim.SGD(model.parameters(), lr)
logs = fit(epochs, model, optimizer, train_loader, val_loader)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# epoch 1: validation cost = 1.903, validation accuracy = 0.313
# epoch 2: validation cost = 1.751, validation accuracy = 0.381
# epoch 3: validation cost = 1.735, validation accuracy = 0.377
# epoch 4: validation cost = 1.66, validation accuracy = 0.405
# epoch 5: validation cost = 1.667, validation accuracy = 0.409
# epoch 6: validation cost = 1.64, validation accuracy = 0.416
# epoch 7: validation cost = 1.609, validation accuracy = 0.429
# epoch 8: validation cost = 1.542, validation accuracy = 0.451
# epoch 9: validation cost = 1.534, validation accuracy = 0.452
# epoch 10: validation cost = 1.568, validation accuracy = 0.45

# %%
epochs = 20
lr = 1e-2
optimizer = torch.optim.SGD(model.parameters(), lr)
logs = fit(epochs, model, optimizer, train_loader, val_loader)
# Out:
# epoch 1: validation cost = 1.459, validation accuracy = 0.482
# epoch 2: validation cost = 1.456, validation accuracy = 0.483
# epoch 3: validation cost = 1.45, validation accuracy = 0.484
# epoch 4: validation cost = 1.445, validation accuracy = 0.489
# epoch 5: validation cost = 1.446, validation accuracy = 0.487
# epoch 6: validation cost = 1.443, validation accuracy = 0.488
# epoch 7: validation cost = 1.441, validation accuracy = 0.49
# epoch 8: validation cost = 1.442, validation accuracy = 0.493
# epoch 9: validation cost = 1.439, validation accuracy = 0.495
# epoch 10: validation cost = 1.437, validation accuracy = 0.493
# epoch 11: validation cost = 1.435, validation accuracy = 0.492
# epoch 12: validation cost = 1.433, validation accuracy = 0.493
# epoch 13: validation cost = 1.435, validation accuracy = 0.495
# epoch 14: validation cost = 1.433, validation accuracy = 0.491
# epoch 15: validation cost = 1.427, validation accuracy = 0.496
# epoch 16: validation cost = 1.428, validation accuracy = 0.495
# epoch 17: validation cost = 1.432, validation accuracy = 0.497
# epoch 18: validation cost = 1.423, validation accuracy = 0.5
# epoch 19: validation cost = 1.424, validation accuracy = 0.494
# epoch 20: validation cost = 1.424, validation accuracy = 0.498

# %%
accuracies = [log['accuracy'] for log in logs]
plt.plot(accuracies, '-x')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.title("Accuracy vs. No. of epoch")
plt.show();

# %%
costs = [log['cost'] for log in logs]
plt.plot(costs, '-x')
plt.xlabel('epoch')
plt.ylabel('cost')
plt.title("Cost vs. No. of epoch")
plt.show();

# %% [markdown]
# **Evaluation on test set**

# %%
batch_evals = [model.evaluate(batch) for batch in test_loader]
res = evaluateEpoch(batch_evals)
print('test cost = {}, test accuracy = {}'.format(res['cost'], res['accuracy']))
# Out:
# test cost = 1.38, test accuracy = 0.51

# %%
# save model
torch.save(model.state_dict(), "cifar10.pth")
